# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Deliverable #1 - #2
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
#Deliverable #1 - #4
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Import the requests library.
import requests

#import the API key
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Deliverable #1 - 5 and 6
#Create an empty list to hold the weather data
city_data = []
#Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list.
#for i range(len(cities)):
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 the the record count
    record_count += 1
    
#Run an API request for each of the cities
    try:
        #Parse the JSON data and retrieve data.
        city_weather = requests.get(city_url).json()
       
        #Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
                        
        
#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass #not good practice to use pass statement in except block
    
#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | high rock
# Processing Record 2 of Set 1 | mesyagutovo
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | oistins
# Processing Record 7 of Set 1 | vestmanna
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | berlevag
# Processing Record 13 of Set 1 | quesnel
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | hualmay
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | pisco
# Processing Record 20 of Set 1 | jaguaruna
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | narsaq
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | ulkan
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | sur
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | hammerfest
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | constitucion
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | monkey bay
# Processing Record 43 of Set 1 | faya
# Processing Record 44 of Set 1 | kaoma
# Processing Record 45 of Set 1 | boa vista
# Processing Record 46 of Set 1 | easton
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | katsuura
# Processing Record 49 of Set 1 | altay
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | baie-comeau
# Processing Record 3 of Set 2 | anadyr
# Processing Record 4 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | challans
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | cayenne
# Processing Record 10 of Set 2 | otane
# Processing Record 11 of Set 2 | magadan
# Processing Record 12 of Set 2 | shelburne
# Processing Record 13 of Set 2 | alice springs
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | morondava
# Processing Record 16 of Set 2 | berezovyy
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | bubaque
# Processing Record 19 of Set 2 | berbera
# Processing Record 20 of Set 2 | tilichiki
# Processing Record 21 of Set 2 | inverell
# Processing Record 22 of Set 2 | santa isabel do rio negro
# Processing Record 23 of Set 2 | sovetskiy
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | marfino
# Processing Record 26 of Set 2 | spornoye
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | waingapu
# Processing Record 30 of Set 2 | isangel
# Processing Record 31 of Set 2 | xining
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | san policarpo
# Processing Record 36 of Set 2 | zinder
# Processing Record 37 of Set 2 | arari
# Processing Record 38 of Set 2 | tikrit
# Processing Record 39 of Set 2 | henties bay
# Processing Record 40 of Set 2 | chengde
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | tahoua
# Processing Record 43 of Set 2 | mbini
# Processing Record 44 of Set 2 | arlit
# Processing Record 45 of Set 2 | marabba
# Processing Record 46 of Set 2 | ugoofaaru
# Processing Record 47 of Set 2 | souillac
# Processing Record 48 of Set 2 | takoradi
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | tahe
# Processing Record 2 of Set 3 | fare
# Processing Record 3 of Set 3 | dayong
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | komsomolskiy
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | jiguani
# Processing Record 10 of Set 3 | north myrtle beach
# Processing Record 11 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 12 of Set 3 | tarko-sale
# Processing Record 13 of Set 3 | cidreira
# Processing Record 14 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | tomatlan
# Processing Record 17 of Set 3 | kaeo
# Processing Record 18 of Set 3 | nanakuli
# Processing Record 19 of Set 3 | yar-sale
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | mazagao
# Processing Record 23 of Set 3 | bridlington
# Processing Record 24 of Set 3 | skibbereen
# Processing Record 25 of Set 3 | jalu
# Processing Record 26 of Set 3 | alihe
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | darnah
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | barinas
# Processing Record 31 of Set 3 | mount isa
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | port shepstone
# Processing Record 34 of Set 3 | auki
# Processing Record 35 of Set 3 | zhezkazgan
# Processing Record 36 of Set 3 | buala
# Processing Record 37 of Set 3 | vilyuysk
# Processing Record 38 of Set 3 | saint-francois
# Processing Record 39 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | berezniki
# Processing Record 42 of Set 3 | kungurtug
# Processing Record 43 of Set 3 | tarakan
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | qaanaaq
# Processing Record 46 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 3 | moussoro
# Processing Record 48 of Set 3 | vanimo
# Processing Record 49 of Set 3 | tasiilaq
# Processing Record 50 of Set 3 | gibraltar
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | roebourne
# Processing Record 3 of Set 4 | mackay
# Processing Record 4 of Set 4 | aitape
# Processing Record 5 of Set 4 | bouna
# Processing Record 6 of Set 4 | atambua
# Processing Record 7 of Set 4 | tatarskaya pishlya
# Processing Record 8 of Set 4 | grand gaube
# Processing Record 9 of Set 4 | kollumerland
# City not found. Skipping...
# Processing Record 10 of Set 4 | mouila
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | kryvyy rih
# Processing Record 13 of Set 4 | asau
# Processing Record 14 of Set 4 | saint george
# Processing Record 15 of Set 4 | vaini
# Processing Record 16 of Set 4 | shiyan
# Processing Record 17 of Set 4 | dalvik
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | bay roberts
# Processing Record 20 of Set 4 | yarmouth
# Processing Record 21 of Set 4 | kikwit
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | betioky
# Processing Record 24 of Set 4 | saint anthony
# Processing Record 25 of Set 4 | coahuayana
# Processing Record 26 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 4 | morro bay
# Processing Record 28 of Set 4 | eureka
# Processing Record 29 of Set 4 | mayo
# Processing Record 30 of Set 4 | tautira
# Processing Record 31 of Set 4 | ouadda
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | yatou
# Processing Record 34 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 4 | kiunga
# Processing Record 36 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | lompoc
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | georgetown
# Processing Record 41 of Set 4 | heihe
# Processing Record 42 of Set 4 | auch
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | qaqortoq
# Processing Record 45 of Set 4 | port hardy
# Processing Record 46 of Set 4 | bolshaya martynovka
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | paamiut
# Processing Record 3 of Set 5 | fort nelson
# Processing Record 4 of Set 5 | tumaco
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | svetlogorsk
# Processing Record 7 of Set 5 | karratha
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | naze
# Processing Record 10 of Set 5 | havoysund
# Processing Record 11 of Set 5 | rio gallegos
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | alto araguaia
# Processing Record 14 of Set 5 | lebyazhye
# Processing Record 15 of Set 5 | bundaberg
# Processing Record 16 of Set 5 | tikhvin
# Processing Record 17 of Set 5 | mount gambier
# Processing Record 18 of Set 5 | bafq
# Processing Record 19 of Set 5 | tarata
# Processing Record 20 of Set 5 | chapais
# Processing Record 21 of Set 5 | parana
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 5 | cabo san lucas
# Processing Record 25 of Set 5 | ambulu
# Processing Record 26 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 5 | glencoe
# Processing Record 28 of Set 5 | monrovia
# Processing Record 29 of Set 5 | sumy
# Processing Record 30 of Set 5 | rabaul
# Processing Record 31 of Set 5 | saint-augustin
# Processing Record 32 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 5 | cotonou
# Processing Record 34 of Set 5 | flinders
# Processing Record 35 of Set 5 | merke
# Processing Record 36 of Set 5 | shevchenkove
# Processing Record 37 of Set 5 | timaru
# Processing Record 38 of Set 5 | lichinga
# Processing Record 39 of Set 5 | mitha tiwana
# Processing Record 40 of Set 5 | vao
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | miri
# Processing Record 43 of Set 5 | omboue
# Processing Record 44 of Set 5 | rocha
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | beringovskiy
# Processing Record 47 of Set 5 | castro
# Processing Record 48 of Set 5 | sept-iles
# Processing Record 49 of Set 5 | coihaique
# Processing Record 50 of Set 5 | simao
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | ambilobe
# Processing Record 4 of Set 6 | mae sai
# Processing Record 5 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 6 | pingliang
# Processing Record 7 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 6 | ahipara
# Processing Record 9 of Set 6 | urucui
# Processing Record 10 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 11 of Set 6 | barao de melgaco
# Processing Record 12 of Set 6 | marsh harbour
# Processing Record 13 of Set 6 | la palma
# Processing Record 14 of Set 6 | massakory
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | khatanga
# Processing Record 17 of Set 6 | hobyo
# Processing Record 18 of Set 6 | yulara
# Processing Record 19 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 6 | porto novo
# Processing Record 21 of Set 6 | ribeira grande
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | pacific grove
# Processing Record 24 of Set 6 | ayr
# Processing Record 25 of Set 6 | ibra
# Processing Record 26 of Set 6 | lata
# Processing Record 27 of Set 6 | luwuk
# Processing Record 28 of Set 6 | zyryanka
# Processing Record 29 of Set 6 | fort wayne
# Processing Record 30 of Set 6 | macapa
# Processing Record 31 of Set 6 | noshiro
# Processing Record 32 of Set 6 | kruisfontein
# Processing Record 33 of Set 6 | valleyview
# Processing Record 34 of Set 6 | filadelfia
# Processing Record 35 of Set 6 | paysandu
# Processing Record 36 of Set 6 | merauke
# Processing Record 37 of Set 6 | nordby
# Processing Record 38 of Set 6 | manta
# Processing Record 39 of Set 6 | abu samrah
# Processing Record 40 of Set 6 | victoria
# Processing Record 41 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 6 | goedereede
# Processing Record 43 of Set 6 | christchurch
# Processing Record 44 of Set 6 | grindavik
# Processing Record 45 of Set 6 | port hedland
# Processing Record 46 of Set 6 | san carlos de bariloche
# Processing Record 47 of Set 6 | tirumullaivasal
# Processing Record 48 of Set 6 | jardim
# Processing Record 49 of Set 6 | dudinka
# Processing Record 50 of Set 6 | pavino
# Processing Record 1 of Set 7 | suruc
# Processing Record 2 of Set 7 | banda aceh
# Processing Record 3 of Set 7 | bonavista
# Processing Record 4 of Set 7 | terra santa
# Processing Record 5 of Set 7 | te anau
# Processing Record 6 of Set 7 | madimba
# Processing Record 7 of Set 7 | san rafael
# Processing Record 8 of Set 7 | kuala terengganu
# Processing Record 9 of Set 7 | san quintin
# Processing Record 10 of Set 7 | jerusalem
# Processing Record 11 of Set 7 | ayaviri
# Processing Record 12 of Set 7 | kyzyl-suu
# Processing Record 13 of Set 7 | kibondo
# Processing Record 14 of Set 7 | manokwari
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | abramovka
# Processing Record 17 of Set 7 | sinnamary
# Processing Record 18 of Set 7 | jacqueville
# Processing Record 19 of Set 7 | ponta do sol
# Processing Record 20 of Set 7 | canutama
# Processing Record 21 of Set 7 | rezekne
# Processing Record 22 of Set 7 | praia
# Processing Record 23 of Set 7 | lillooet
# Processing Record 24 of Set 7 | sobolevo
# Processing Record 25 of Set 7 | edson
# Processing Record 26 of Set 7 | borgo san lorenzo
# Processing Record 27 of Set 7 | mantua
# Processing Record 28 of Set 7 | pevek
# Processing Record 29 of Set 7 | mandan
# Processing Record 30 of Set 7 | chapleau
# Processing Record 31 of Set 7 | rawson
# Processing Record 32 of Set 7 | buin
# Processing Record 33 of Set 7 | katsina
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | winnemucca
# Processing Record 36 of Set 7 | eirunepe
# Processing Record 37 of Set 7 | port blair
# Processing Record 38 of Set 7 | pajan
# Processing Record 39 of Set 7 | ornskoldsvik
# Processing Record 40 of Set 7 | lake elsinore
# Processing Record 41 of Set 7 | leningradskiy
# Processing Record 42 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 7 | alyangula
# Processing Record 44 of Set 7 | ketchikan
# Processing Record 45 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 46 of Set 7 | puerto ayacucho
# Processing Record 47 of Set 7 | telimele
# Processing Record 48 of Set 7 | yuancheng
# Processing Record 49 of Set 7 | houston
# Processing Record 50 of Set 7 | aykhal
# Processing Record 1 of Set 8 | ust-omchug
# Processing Record 2 of Set 8 | longonjo
# Processing Record 3 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 8 | rovinj
# Processing Record 5 of Set 8 | buzmeyin
# Processing Record 6 of Set 8 | nouakchott
# Processing Record 7 of Set 8 | dwarka
# Processing Record 8 of Set 8 | santa vitoria do palmar
# Processing Record 9 of Set 8 | belmonte
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | touros
# Processing Record 12 of Set 8 | mahebourg
# Processing Record 13 of Set 8 | padang
# Processing Record 14 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 8 | waipawa
# Processing Record 16 of Set 8 | borazjan
# Processing Record 17 of Set 8 | chiang khong
# Processing Record 18 of Set 8 | tadine
# Processing Record 19 of Set 8 | broome
# Processing Record 20 of Set 8 | laguna
# Processing Record 21 of Set 8 | pirgos
# Processing Record 22 of Set 8 | opuwo
# Processing Record 23 of Set 8 | salaga
# Processing Record 24 of Set 8 | beyneu
# Processing Record 25 of Set 8 | port moresby
# Processing Record 26 of Set 8 | bilibino
# Processing Record 27 of Set 8 | tura
# Processing Record 28 of Set 8 | ust-kulom
# Processing Record 29 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 8 | jinotega
# Processing Record 31 of Set 8 | slavsk
# Processing Record 32 of Set 8 | khani
# Processing Record 33 of Set 8 | benghazi
# Processing Record 34 of Set 8 | mikumi
# Processing Record 35 of Set 8 | otaru
# Processing Record 36 of Set 8 | carndonagh
# Processing Record 37 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 38 of Set 8 | lykhivka
# Processing Record 39 of Set 8 | svetlyy
# Processing Record 40 of Set 8 | kargil
# Processing Record 41 of Set 8 | sitka
# Processing Record 42 of Set 8 | meybod
# Processing Record 43 of Set 8 | nipawin
# Processing Record 44 of Set 8 | chapayevka
# Processing Record 45 of Set 8 | inhambane
# Processing Record 46 of Set 8 | luderitz
# Processing Record 47 of Set 8 | pangnirtung
# Processing Record 48 of Set 8 | baruun-urt
# Processing Record 49 of Set 8 | aketi
# Processing Record 50 of Set 8 | alugan
# Processing Record 1 of Set 9 | bahia blanca
# Processing Record 2 of Set 9 | ancud
# Processing Record 3 of Set 9 | bonthe
# Processing Record 4 of Set 9 | ulladulla
# Processing Record 5 of Set 9 | batemans bay
# Processing Record 6 of Set 9 | grenaa
# Processing Record 7 of Set 9 | limon
# Processing Record 8 of Set 9 | itupiranga
# Processing Record 9 of Set 9 | hohhot
# Processing Record 10 of Set 9 | manjhanpur
# Processing Record 11 of Set 9 | novobessergenevka
# Processing Record 12 of Set 9 | boende
# Processing Record 13 of Set 9 | gombong
# Processing Record 14 of Set 9 | acajutla
# Processing Record 15 of Set 9 | klyuchi
# Processing Record 16 of Set 9 | avarua
# Processing Record 17 of Set 9 | mporokoso
# Processing Record 18 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 9 | ekhabi
# Processing Record 20 of Set 9 | moerai
# Processing Record 21 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 9 | lyuban
# Processing Record 23 of Set 9 | falam
# Processing Record 24 of Set 9 | hvolsvollur
# Processing Record 25 of Set 9 | champerico
# Processing Record 26 of Set 9 | korla
# Processing Record 27 of Set 9 | san patricio
# Processing Record 28 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 9 | bethel
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | lorengau
# Processing Record 32 of Set 9 | sibolga
# Processing Record 33 of Set 9 | zhigansk
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 9 | itacoatiara
# Processing Record 37 of Set 9 | bayonet point
# Processing Record 38 of Set 9 | east london
# Processing Record 39 of Set 9 | havre-saint-pierre
# Processing Record 40 of Set 9 | port pirie
# Processing Record 41 of Set 9 | westport
# Processing Record 42 of Set 9 | vila franca do campo
# Processing Record 43 of Set 9 | ghotki
# Processing Record 44 of Set 9 | luganville
# Processing Record 45 of Set 9 | pizarro
# Processing Record 46 of Set 9 | ampanihy
# Processing Record 47 of Set 9 | port-cartier
# Processing Record 48 of Set 9 | katra
# Processing Record 49 of Set 9 | puerto cabezas
# Processing Record 50 of Set 9 | palana
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | kahului
# Processing Record 3 of Set 10 | yichun
# Processing Record 4 of Set 10 | bayan
# Processing Record 5 of Set 10 | wilmington
# Processing Record 6 of Set 10 | xichang
# Processing Record 7 of Set 10 | tateyama
# Processing Record 8 of Set 10 | mildura
# Processing Record 9 of Set 10 | chute-aux-outardes
# Processing Record 10 of Set 10 | ourinhos
# Processing Record 11 of Set 10 | tromso
# Processing Record 12 of Set 10 | catabola
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | bereda
# Processing Record 15 of Set 10 | bambari
# Processing Record 16 of Set 10 | praxedis guerrero
# Processing Record 17 of Set 10 | jiayuguan
# Processing Record 18 of Set 10 | mount pleasant
# Processing Record 19 of Set 10 | kopychyntsi
# Processing Record 20 of Set 10 | kamaishi
# Processing Record 21 of Set 10 | marienburg
# Processing Record 22 of Set 10 | vostok
# Processing Record 23 of Set 10 | selu
# Processing Record 24 of Set 10 | khanpur
# Processing Record 25 of Set 10 | talnakh
# Processing Record 26 of Set 10 | caravelas
# Processing Record 27 of Set 10 | porto torres
# Processing Record 28 of Set 10 | puerto leguizamo
# Processing Record 29 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 10 | bad doberan
# Processing Record 31 of Set 10 | abonnema
# Processing Record 32 of Set 10 | puerto penasco
# Processing Record 33 of Set 10 | trairi
# Processing Record 34 of Set 10 | oudtshoorn
# Processing Record 35 of Set 10 | baykit
# Processing Record 36 of Set 10 | chatrapur
# Processing Record 37 of Set 10 | aden
# Processing Record 38 of Set 10 | lazarev
# Processing Record 39 of Set 10 | avila
# Processing Record 40 of Set 10 | general roca
# Processing Record 41 of Set 10 | muscat
# Processing Record 42 of Set 10 | sile
# Processing Record 43 of Set 10 | mareeba
# Processing Record 44 of Set 10 | okhotsk
# Processing Record 45 of Set 10 | renqiu
# Processing Record 46 of Set 10 | olafsvik
# Processing Record 47 of Set 10 | madang
# Processing Record 48 of Set 10 | svirstroy
# Processing Record 49 of Set 10 | lagos
# Processing Record 50 of Set 10 | hof
# Processing Record 1 of Set 11 | ngawi
# Processing Record 2 of Set 11 | taoudenni
# Processing Record 3 of Set 11 | palmer
# Processing Record 4 of Set 11 | cherskiy
# Processing Record 5 of Set 11 | norman wells
# Processing Record 6 of Set 11 | avera
# Processing Record 7 of Set 11 | dhidhdhoo
# Processing Record 8 of Set 11 | isla vista
# Processing Record 9 of Set 11 | denpasar
# Processing Record 10 of Set 11 | sabinopolis
# Processing Record 11 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 12 of Set 11 | kidal
# Processing Record 13 of Set 11 | vallenar
# Processing Record 14 of Set 11 | barahona
# Processing Record 15 of Set 11 | seymchan
# Processing Record 16 of Set 11 | chenghai
# Processing Record 17 of Set 11 | marzuq
# Processing Record 18 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 11 | bahia de caraquez
# Processing Record 20 of Set 11 | nyagan
# Processing Record 21 of Set 11 | aanekoski
# Processing Record 22 of Set 11 | anloga
# Processing Record 23 of Set 11 | udachnyy
# Processing Record 24 of Set 11 | leshukonskoye
# Processing Record 25 of Set 11 | berdigestyakh
# Processing Record 26 of Set 11 | thinadhoo
# Processing Record 27 of Set 11 | mabaruma
# Processing Record 28 of Set 11 | esperance
# Processing Record 29 of Set 11 | cabra
# Processing Record 30 of Set 11 | almaznyy
# Processing Record 31 of Set 11 | upington
# Processing Record 32 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 11 | nenjiang
# Processing Record 34 of Set 11 | richards bay
# Processing Record 35 of Set 11 | astana
# Processing Record 36 of Set 11 | hirara
# Processing Record 37 of Set 11 | kandri
# Processing Record 38 of Set 11 | qasigiannguit
# Processing Record 39 of Set 11 | siva
# Processing Record 40 of Set 11 | juxtlahuaca
# Processing Record 41 of Set 11 | la ronge
# Processing Record 42 of Set 11 | alenquer
# Processing Record 43 of Set 11 | zheleznodorozhnyy
# Processing Record 44 of Set 11 | svetlaya
# Processing Record 45 of Set 11 | axim
# Processing Record 46 of Set 11 | guerrero negro
# Processing Record 47 of Set 11 | krasnoye
# Processing Record 48 of Set 11 | severo-kurilsk
# Processing Record 49 of Set 11 | ambon
# Processing Record 50 of Set 11 | xuddur
# Processing Record 1 of Set 12 | vermillion
# Processing Record 2 of Set 12 | kaili
# Processing Record 3 of Set 12 | stangaceaua
# City not found. Skipping...
# Processing Record 4 of Set 12 | chara
# Processing Record 5 of Set 12 | krikellos
# Processing Record 6 of Set 12 | kovur
# Processing Record 7 of Set 12 | krasnouralsk
# Processing Record 8 of Set 12 | kyshtovka
# Processing Record 9 of Set 12 | mitchell
# Processing Record 10 of Set 12 | mokhsogollokh
# Processing Record 11 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 12 | nyurba
# Processing Record 13 of Set 12 | gweru
# Processing Record 14 of Set 12 | gonbad-e qabus
# Processing Record 15 of Set 12 | bud
# Processing Record 16 of Set 12 | saquarema
# Processing Record 17 of Set 12 | santa ana
# Processing Record 18 of Set 12 | krasnoselkup
# Processing Record 19 of Set 12 | nicoya
# Processing Record 20 of Set 12 | tyrma
# Processing Record 21 of Set 12 | mandalgovi
# Processing Record 22 of Set 12 | sabha
# Processing Record 23 of Set 12 | walvis bay
# Processing Record 24 of Set 12 | port augusta
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 12 | luena
# Processing Record 28 of Set 12 | turukhansk
# Processing Record 29 of Set 12 | ghelari
# Processing Record 30 of Set 12 | santa vitoria
# Processing Record 31 of Set 12 | viana
# Processing Record 32 of Set 12 | ipira
# Processing Record 33 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 12 | lakes entrance
# Processing Record 35 of Set 12 | kapit
# Processing Record 36 of Set 12 | cristalina
# Processing Record 37 of Set 12 | kununurra
# Processing Record 38 of Set 12 | ozernovskiy
# Processing Record 39 of Set 12 | hambantota
# Processing Record 40 of Set 12 | zhangjiakou
# Processing Record 41 of Set 12 | columbus
# Processing Record 42 of Set 12 | makakilo city
# Processing Record 43 of Set 12 | aquidauana
# Processing Record 44 of Set 12 | camacha
# Processing Record 45 of Set 12 | atbasar
# Processing Record 46 of Set 12 | olga
# Processing Record 47 of Set 12 | apache junction
# Processing Record 48 of Set 12 | inuvik
# Processing Record 49 of Set 12 | roma
# Processing Record 50 of Set 12 | misratah
# Processing Record 1 of Set 13 | victor harbor
# Processing Record 2 of Set 13 | port-gentil
# Processing Record 3 of Set 13 | sangar
# Processing Record 4 of Set 13 | tayginka
# Processing Record 5 of Set 13 | lethem
# Processing Record 6 of Set 13 | grajau
# Processing Record 7 of Set 13 | hoganas
# Processing Record 8 of Set 13 | banjar
# Processing Record 9 of Set 13 | deputatskiy
# Processing Record 10 of Set 13 | shingu
# Processing Record 11 of Set 13 | ati
# Processing Record 12 of Set 13 | bumiayu
# Processing Record 13 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 13 | turgenevo
# Processing Record 15 of Set 13 | manaus
# Processing Record 16 of Set 13 | cairns
# Processing Record 17 of Set 13 | biak
# Processing Record 18 of Set 13 | colac
# Processing Record 19 of Set 13 | tabou
# Processing Record 20 of Set 13 | marawi
# Processing Record 21 of Set 13 | nizhniy tsasuchey
# Processing Record 22 of Set 13 | gravdal
# Processing Record 23 of Set 13 | jinchang
# Processing Record 24 of Set 13 | luanda
# Processing Record 25 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 26 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 13 | wiang sa
# Processing Record 28 of Set 13 | sibu
# Processing Record 29 of Set 13 | griffith
# Processing Record 30 of Set 13 | anajatuba
# Processing Record 31 of Set 13 | bandar
# Processing Record 32 of Set 13 | ankara
# Processing Record 33 of Set 13 | shirokiy
# Processing Record 34 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 35 of Set 13 | vardo
# Processing Record 36 of Set 13 | champoton
# Processing Record 37 of Set 13 | cockburn town
# Processing Record 38 of Set 13 | sao mateus do maranhao
# Processing Record 39 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 40 of Set 13 | santa rosalia
# Processing Record 41 of Set 13 | sicamous
# Processing Record 42 of Set 13 | genhe
# Processing Record 43 of Set 13 | hellvik
# Processing Record 44 of Set 13 | srandakan
# Processing Record 45 of Set 13 | comodoro rivadavia
# Processing Record 46 of Set 13 | turayf
# Processing Record 47 of Set 13 | sal rei
# Processing Record 48 of Set 13 | malindi
# Processing Record 49 of Set 13 | bilma
# Processing Record 50 of Set 13 | teguldet
# Processing Record 1 of Set 14 | ilulissat
# Processing Record 2 of Set 14 | tiznit
# Processing Record 3 of Set 14 | lincoln
# Processing Record 4 of Set 14 | omsukchan
# Processing Record 5 of Set 14 | newcastle
# Processing Record 6 of Set 14 | luzhou
# Processing Record 7 of Set 14 | honningsvag
# Processing Record 8 of Set 14 | zeya
# Processing Record 9 of Set 14 | phan thiet
# Processing Record 10 of Set 14 | fraga
# Processing Record 11 of Set 14 | sao jose da coroa grande
# Processing Record 12 of Set 14 | mitsamiouli
# Processing Record 13 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 14 | bambui
# Processing Record 15 of Set 14 | fairbanks
# Processing Record 16 of Set 14 | mersing
# Processing Record 17 of Set 14 | maun
# Processing Record 18 of Set 14 | beloha
# Processing Record 19 of Set 14 | sikeston
# Processing Record 20 of Set 14 | amapa
# Processing Record 21 of Set 14 | ahuimanu
# Processing Record 22 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 14 | lakatoro
# Processing Record 24 of Set 14 | horta
# Processing Record 25 of Set 14 | jumla
# Processing Record 26 of Set 14 | gardan diwal
# City not found. Skipping...
# Processing Record 27 of Set 14 | santa fe
# Processing Record 28 of Set 14 | pandua
# Processing Record 29 of Set 14 | archdale
# Processing Record 30 of Set 14 | straumen
# Processing Record 31 of Set 14 | rongcheng
# Processing Record 32 of Set 14 | hay river
# Processing Record 33 of Set 14 | podosinovets
# Processing Record 34 of Set 14 | poronaysk
# Processing Record 35 of Set 14 | varhaug
# Processing Record 36 of Set 14 | aktau
# Processing Record 37 of Set 14 | the valley
# Processing Record 38 of Set 14 | stokmarknes
# Processing Record 39 of Set 14 | russell
# Processing Record 40 of Set 14 | piacabucu
# Processing Record 41 of Set 14 | korem
# Processing Record 42 of Set 14 | ludza
# Processing Record 43 of Set 14 | zapolyarnyy
# Processing Record 44 of Set 14 | rundu
# Processing Record 45 of Set 14 | basoko
# Processing Record 46 of Set 14 | raga
# Processing Record 47 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 14 | uray
# Processing Record 49 of Set 14 | mansa
# Processing Record 50 of Set 14 | vazante
# Processing Record 1 of Set 15 | harrison
# Processing Record 2 of Set 15 | lagunas
# Processing Record 3 of Set 15 | bandarbeyla
# Processing Record 4 of Set 15 | ribeirao branco
# Processing Record 5 of Set 15 | ust-ilimsk
# Processing Record 6 of Set 15 | hofn
# Processing Record 7 of Set 15 | marrakesh
# Processing Record 8 of Set 15 | betamcherla
# Processing Record 9 of Set 15 | puerto madero
# Processing Record 10 of Set 15 | nizwa
# Processing Record 11 of Set 15 | ballstad
# City not found. Skipping...
# Processing Record 12 of Set 15 | port macquarie
# Processing Record 13 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 14 of Set 15 | pietarsaari
# Processing Record 15 of Set 15 | kenai
# Processing Record 16 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 15 | tucumcari
# Processing Record 18 of Set 15 | linjiang
# Processing Record 19 of Set 15 | erenhot
# Processing Record 20 of Set 15 | atagay
# Processing Record 21 of Set 15 | ndouci
# City not found. Skipping...
# Processing Record 22 of Set 15 | springbok
# Processing Record 23 of Set 15 | royan
# Processing Record 24 of Set 15 | shuangcheng
# Processing Record 25 of Set 15 | biasca
# Processing Record 26 of Set 15 | hoquiam
# Processing Record 27 of Set 15 | marsa matruh
# Processing Record 28 of Set 15 | ankang
# Processing Record 29 of Set 15 | cap malheureux
# Processing Record 30 of Set 15 | bac giang
# Processing Record 31 of Set 15 | posse
# Processing Record 32 of Set 15 | san jose
# Processing Record 33 of Set 15 | oksovskiy
# Processing Record 34 of Set 15 | languyan
# Processing Record 35 of Set 15 | olinda
# Processing Record 36 of Set 15 | staryy nadym
# Processing Record 37 of Set 15 | kafanchan
# Processing Record 38 of Set 15 | damietta
# Processing Record 39 of Set 15 | puerto cabello
# Processing Record 40 of Set 15 | dakar
# Processing Record 41 of Set 15 | beruwala
# Processing Record 42 of Set 15 | great yarmouth
# Processing Record 43 of Set 15 | gorele
# Processing Record 44 of Set 15 | bambanglipuro
# Processing Record 45 of Set 15 | spassk
# Processing Record 46 of Set 15 | kamarion
# Processing Record 47 of Set 15 | bukachacha
# Processing Record 48 of Set 15 | torva
# Processing Record 49 of Set 15 | san jeronimo
# Processing Record 50 of Set 15 | muravlenko
# Processing Record 1 of Set 16 | allapalli
# Processing Record 2 of Set 16 | piet retief
# Processing Record 3 of Set 16 | date
# Processing Record 4 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 16 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 16 | dukat
# Processing Record 7 of Set 16 | peniche
# Processing Record 8 of Set 16 | muana
# Processing Record 9 of Set 16 | evensk
# Processing Record 10 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 16 | sovetskaya gavan
# Processing Record 12 of Set 16 | bagotville
# Processing Record 13 of Set 16 | si sa ket
# Processing Record 14 of Set 16 | davila
# Processing Record 15 of Set 16 | seoul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Deliverable #1 - 7.)
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     High Rock      BS  26.6208  -78.2833     78.82        76          53
# 1   Mesyagutovo      RU  55.5303   58.2528     39.40        93         100
# 2         Tiksi      RU  71.6872  128.8694     32.00        90           7
# 3  Puerto Ayora      EC  -0.7393  -90.3518     71.83        91          34
# 4         Airai      TL  -8.9266  125.4092     72.36        48           9
# 5       Oistins      BB  13.0667  -59.5333     79.12        77          98
# 6     Vestmanna      FO  62.1564   -7.1664     45.52        93          75
# 7     Saskylakh      RU  71.9167  114.0833     33.15        96         100
# 8   Tuktoyaktuk      CA  69.4541 -133.0374     29.84        72          80
# 9     Jamestown      US  42.0970  -79.2353     50.05        97          40
#
#    Wind Speed Current Description
# 0       15.12       broken clouds
# 1        3.02          light rain
# 2        3.98           clear sky
# 3        6.96    scattered clouds
# 4        5.08           clear sky
# 5       12.50     overcast clouds
# 6        2.30       broken clouds
# 7       10.22     overcast clouds
# 8       10.63       broken clouds
# 9        0.00    scattered clouds

# %%
#Deliverable #1 - #8
#Create the output file(CSV)
output_data_file = "Weather_Database/Weather_Database.csv"
#Export the City_data into a CSV
city_data_df.to_csv(output_data_file,index_label="City_ID")
